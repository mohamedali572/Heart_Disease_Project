# %% [markdown]
# # Feature Selection
# This notebook demonstrates Recursive Feature Elimination (RFE) to select the top 5 important features.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

# Initialize model
model = RandomForestClassifier()

# Apply RFE to select 5 features
rfe = RFE(model, 5)
fit = rfe.fit(data.drop('target', axis=1), data['target'])

print("Selected Features:")
print(fit.support_)
