# %% [markdown]
# # Hyperparameter Tuning
# This notebook uses GridSearchCV to optimize model hyperparameters and saves the best model.

# %%
from sklearn.model_selection import GridSearchCV
import joblib

# Define parameter grid
param_grid = {'n_estimators': [10, 50, 100]}

# Apply GridSearchCV on RandomForestClassifier
grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=3)
grid_search.fit(X_train, y_train)

# Save best model
joblib.dump(grid_search.best_estimator_, '../models/final_model.pkl')
